# %% [markdown]
# # Import the necessary libraries

# %%
#Import all the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=7,6
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import pickle

# %% [markdown]
# # Load the Dataframe

# %%
#Create the dataframe 'iris'

iris=pd.read_csv('Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#checking the number of rows and columns of the dataframe

iris.shape
# Out:
# (150, 6)

# %% [markdown]
# There are 150 rows and 6 columns in the dataframe

# %%
#List any 5 random rows from the dataset

iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 31    32            5.4           3.4            1.5           0.4
# 116  117            6.5           3.0            5.5           1.8
# 95    96            5.7           3.0            4.2           1.2
# 131  132            7.9           3.8            6.4           2.0
# 86    87            6.7           3.1            4.7           1.5
#
#              Species
# 31       Iris-setosa
# 116   Iris-virginica
# 95   Iris-versicolor
# 131   Iris-virginica
# 86   Iris-versicolor

# %%
#list the first 5 rows of the dataframe

iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#list the last 5 rows of the dataframe

iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#checking the datatypes of all the columns in the dataframe
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#finding all the statistics measures of the dataframe

iris.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_1dfde_row0_col0, #T_1dfde_row0_col1, #T_1dfde_row0_col2, #T_1dfde_row0_col3, #T_1dfde_row0_col4, #T_1dfde_row7_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1dfde_row1_col0, #T_1dfde_row5_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_1dfde_row1_col1, #T_1dfde_row5_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_1dfde_row1_col2, #T_1dfde_row1_col3, #T_1dfde_row4_col2, #T_1dfde_row5_col2, #T_1dfde_row6_col2, #T_1dfde_row7_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1dfde_row1_col4, #T_1dfde_row2_col3, #T_1dfde_row2_col4, #T_1dfde_row4_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_1dfde_row2_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_1dfde_row2_col1, #T_1dfde_row2_col2, #T_1dfde_row3_col0, #T_1dfde_row3_col3, #T_1dfde_row3_col4, #T_1dfde_row4_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1dfde_row3_col1, #T_1dfde_row5_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1dfde_row3_col2, #T_1dfde_row5_col4, #T_1dfde_row6_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_1dfde_row4_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_1dfde_row4_col1, #T_1dfde_row6_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_1dfde_row6_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_1dfde_row6_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_1dfde_row7_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_1dfde_row7_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_1dfde_row7_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# </style>
# <table id="T_1dfde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1dfde_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_1dfde_level0_col1" class="col_heading level0 col1" >SepalLengthCm</th>
#       <th id="T_1dfde_level0_col2" class="col_heading level0 col2" >SepalWidthCm</th>
#       <th id="T_1dfde_level0_col3" class="col_heading level0 col3" >PetalLengthCm</th>
#       <th id="T_1dfde_level0_col4" class="col_heading level0 col4" >PetalWidthCm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dfde_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_1dfde_row0_col0" class="data row0 col0" >150.000000</td>
#       <td id="T_1dfde_row0_col1" class="data row0 col1" >150.000000</td>
#       <td id="T_1dfde_row0_col2" class="data row0 col2" >150.000000</td>
#       <td id="T_1dfde_row0_col3" class="data row0 col3" >150.000000</td>
#       <td id="T_1dfde_row0_col4" class="data row0 col4" >150.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1dfde_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_1dfde_row1_col0" class="data row1 col0" >75.500000</td>
#       <td id="T_1dfde_row1_col1" class="data row1 col1" >5.843333</td>
#       <td id="T_1dfde_row1_col2" class="data row1 col2" >3.054000</td>
#       <td id="T_1dfde_row1_col3" class="data row1 col3" >3.758667</td>
#       <td id="T_1dfde_row1_col4" class="data row1 col4" >1.198667</td>
#     </tr>
#     <tr>
#       <th id="T_1dfde_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_1dfde_row2_col0" class="data row2 col0" >43.445368</td>
#       <td id="T_1dfde_row2_col1" class="data row2 col1" >0.828066</td>
#       <td id="T_1dfde_row2_col2" class="data row2 col2" >0.433594</td>
#       <td id="T_1dfde_row2_col3" class="data row2 col3" >1.764420</td>
#       <td id="T_1dfde_row2_col4" class="data row2 col4" >0.763161</td>
#     </tr>
#     <tr>
#       <th id="T_1dfde_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_1dfde_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_1dfde_row3_col1" class="data row3 col1" >4.300000</td>
#       <td id="T_1dfde_row3_col2" class="data row3 col2" >2.000000</td>
#       <td id="T_1dfde_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1dfde_row3_col4" class="data row3 col4" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_1dfde_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_1dfde_row4_col0" class="data row4 col0" >38.250000</td>
#       <td id="T_1dfde_row4_col1" class="data row4 col1" >5.100000</td>
#       <td id="T_1dfde_row4_col2" class="data row4 col2" >2.800000</td>
#       <td id="T_1dfde_row4_col3" class="data row4 col3" >1.600000</td>
#       <td id="T_1dfde_row4_col4" class="data row4 col4" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_1dfde_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_1dfde_row5_col0" class="data row5 col0" >75.500000</td>
#       <td id="T_1dfde_row5_col1" class="data row5 col1" >5.800000</td>
#       <td id="T_1dfde_row5_col2" class="data row5 col2" >3.000000</td>
#       <td id="T_1dfde_row5_col3" class="data row5 col3" >4.350000</td>
#       <td id="T_1dfde_row5_col4" class="data row5 col4" >1.300000</td>
#     </tr>
#     <tr>
#       <th id="T_1dfde_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_1dfde_row6_col0" class="data row6 col0" >112.750000</td>
#       <td id="T_1dfde_row6_col1" class="data row6 col1" >6.400000</td>
#       <td id="T_1dfde_row6_col2" class="data row6 col2" >3.300000</td>
#       <td id="T_1dfde_row6_col3" class="data row6 col3" >5.100000</td>
#       <td id="T_1dfde_row6_col4" class="data row6 col4" >1.800000</td>
#     </tr>
#     <tr>
#       <th id="T_1dfde_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_1dfde_row7_col0" class="data row7 col0" >150.000000</td>
#       <td id="T_1dfde_row7_col1" class="data row7 col1" >7.900000</td>
#       <td id="T_1dfde_row7_col2" class="data row7 col2" >4.400000</td>
#       <td id="T_1dfde_row7_col3" class="data row7 col3" >6.900000</td>
#       <td id="T_1dfde_row7_col4" class="data row7 col4" >2.500000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Plotting the statistical values in a plot

iris.describe().plot()
plt.title('Statistical Values of the dataframe')
plt.show()

# %%
#Checking for the null values of the dataframe

iris.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# There are no null values in the dataframe

# %%
#Drop the columns that are not necessary for training the model

iris=iris.drop(['Id'],axis='columns')
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Plot the distribution of different species using barplot

colors=['red','green','yellow']
iris['Species'].value_counts().plot(kind='bar',color=colors)
plt.show()

# %%
iris['Species'].value_counts().plot(kind='pie',autopct='%.2f',shadow=True,explode=(0.1,0.1,0.1))
plt.show()

# %%
sns.scatterplot(data=iris, x="SepalLengthCm", y="SepalWidthCm",hue="Species")
plt.show()

# %%
sns.scatterplot(data=iris, x="PetalLengthCm", y="PetalWidthCm",hue="Species")
plt.show()

# %%
sns.countplot(iris['SepalLengthCm'],color='#FF1493')
plt.ylabel('Sepal Length(in Cm)')
plt.title('Sepal Length')
plt.show()
sns.countplot(iris['SepalWidthCm'],color='#80FF00')
plt.title('Sepal Width')
plt.ylabel('Sepal Width(in Cm)')
plt.show()

# %%
sns.countplot(iris['PetalLengthCm'],color='#FDEE00')
plt.ylabel('PetalLength(in Cm)')
plt.title('Petal Length')
plt.show()
sns.countplot(iris['PetalWidthCm'],color='#7F1734')
plt.title('Petal Width')
plt.ylabel('Petal Width(in Cm)')
plt.show()

# %% [markdown]
# Checking for Outliers

# %%
sns.boxplot(iris['SepalLengthCm'],color='#FF0000')
plt.show()

# %%
sns.boxplot(iris['SepalWidthCm'],color='#7CFC00')
plt.show()

# %%
sns.boxplot(iris['PetalLengthCm'],color='#FF1493')
plt.show()

# %%
sns.boxplot(iris['PetalWidthCm'],color='#FFFF00')
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Checking for skewness

# %%
iris['SepalLengthCm'].skew()
# Out:
# 0.3149109566369728

# %%
plt.subplot(121)
stats.probplot(iris['SepalLengthCm'],dist="norm",plot=plt)
plt.title('Sepal Length')
plt.show()

# %%
sns.distplot(iris['SepalLengthCm'],color='red')
plt.show()

# %%
iris['SepalWidthCm'].skew()
# Out:
# 0.3340526621720866

# %%
plt.subplot(121)
stats.probplot(iris['SepalWidthCm'],dist="norm",plot=plt)
plt.title('Sepal Width')
plt.show()

# %%
sns.distplot(iris['SepalWidthCm'],color='#CAE00D')
plt.show()

# %%
iris['PetalLengthCm'].skew()
# Out:
# -0.27446425247378287

# %%
plt.subplot(121)
stats.probplot(iris['PetalLengthCm'],dist="norm",plot=plt)
plt.title('Petal Length')
plt.show()

# %%
sns.distplot(iris['PetalLengthCm'],color='green')
plt.show()

# %%
iris['PetalWidthCm'].skew()
# Out:
# -0.10499656214412734

# %%
plt.subplot(121)
stats.probplot(iris['PetalWidthCm'],dist="norm",plot=plt)
plt.title('Petal Width')
plt.show()

# %%
sns.distplot(iris['PetalWidthCm'],color='orange')
plt.show()

# %% [markdown]
# Checking correlation between parameters

# %%
sns.set()

# %%
X_train.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_53c42_row0_col0, #T_53c42_row1_col1, #T_53c42_row2_col2, #T_53c42_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_53c42_row0_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_53c42_row0_col2 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_53c42_row0_col3 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_53c42_row1_col0, #T_53c42_row1_col2, #T_53c42_row1_col3, #T_53c42_row2_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_53c42_row2_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_53c42_row2_col3, #T_53c42_row3_col2 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_53c42_row3_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_53c42_row3_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# </style>
# <table id="T_53c42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53c42_level0_col0" class="col_heading level0 col0" >SepalLengthCm</th>
#       <th id="T_53c42_level0_col1" class="col_heading level0 col1" >SepalWidthCm</th>
#       <th id="T_53c42_level0_col2" class="col_heading level0 col2" >PetalLengthCm</th>
#       <th id="T_53c42_level0_col3" class="col_heading level0 col3" >PetalWidthCm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53c42_level0_row0" class="row_heading level0 row0" >SepalLengthCm</th>
#       <td id="T_53c42_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_53c42_row0_col1" class="data row0 col1" >-0.052819</td>
#       <td id="T_53c42_row0_col2" class="data row0 col2" >0.864970</td>
#       <td id="T_53c42_row0_col3" class="data row0 col3" >0.808314</td>
#     </tr>
#     <tr>
#       <th id="T_53c42_level0_row1" class="row_heading level0 row1" >SepalWidthCm</th>
#       <td id="T_53c42_row1_col0" class="data row1 col0" >-0.052819</td>
#       <td id="T_53c42_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_53c42_row1_col2" class="data row1 col2" >-0.378240</td>
#       <td id="T_53c42_row1_col3" class="data row1 col3" >-0.317901</td>
#     </tr>
#     <tr>
#       <th id="T_53c42_level0_row2" class="row_heading level0 row2" >PetalLengthCm</th>
#       <td id="T_53c42_row2_col0" class="data row2 col0" >0.864970</td>
#       <td id="T_53c42_row2_col1" class="data row2 col1" >-0.378240</td>
#       <td id="T_53c42_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_53c42_row2_col3" class="data row2 col3" >0.960310</td>
#     </tr>
#     <tr>
#       <th id="T_53c42_level0_row3" class="row_heading level0 row3" >PetalWidthCm</th>
#       <td id="T_53c42_row3_col0" class="data row3 col0" >0.808314</td>
#       <td id="T_53c42_row3_col1" class="data row3 col1" >-0.317901</td>
#       <td id="T_53c42_row3_col2" class="data row3 col2" >0.960310</td>
#       <td id="T_53c42_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
correlations=X_train.corr()
sns.heatmap(correlations,annot=True,fmt='0.2f')
plt.show()

# %% [markdown]
# # Model Training

# %%
X=iris.drop(['Species'],axis='columns')
Y=iris['Species']

# %%
Y.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#Replacing the categorical values with numerical values

Y.replace(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],[1,2,3],inplace=True)

# %%
#Model training

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
##GaussianNB model


gb=GaussianNB()
gb.fit(X_train,y_train)
y_pred=gb.predict(X_test)

##checking the accuracy

ac=accuracy_score(y_test,y_pred)
ac
# Out:
# 0.9666666666666667

# %%
##confusion matrix

matrix=metrics.confusion_matrix(y_pred,y_test)
matrix=metrics.confusion_matrix(y_pred,y_test)
sns.heatmap(matrix,annot=True,cmap='Reds',fmt='0.1f')
plt.xlabel("Predicted Values")
plt.ylabel("Test Values")
plt.title("Confusion Matrix for SVC model")
plt.show()

# %%
##SVC 

sv=SVC()
sv.fit(X_train,y_train)
y_pred=sv.predict(X_test)
##checking the accuracy

ac=accuracy_score(y_test,y_pred)
ac
# Out:
# 1.0

# %%
##confusion matrix

matrix=metrics.confusion_matrix(y_pred,y_test)
matrix
matrix=metrics.confusion_matrix(y_pred,y_test)
sns.heatmap(matrix,annot=True,cmap='YlGnBu',fmt='0.1f')
plt.xlabel("Predicted Values")
plt.ylabel("Test Values")
plt.title("Confusion Matrix for  SVC model")
plt.show()

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
##checking the accuracy

from sklearn.metrics import accuracy_score
ac=accuracy_score(y_test,y_pred)
ac
# Out:
# 0.9666666666666667

# %%
##confusion matrix

from sklearn.metrics import confusion_matrix
matrix=metrics.confusion_matrix(y_pred,y_test)
matrix
matrix=metrics.confusion_matrix(y_pred,y_test)
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(matrix,annot=True,cmap=cmap,fmt='0.1f')
plt.xlabel("Predicted Values")
plt.ylabel("Test Values")
plt.title("Confusion Matrix for  KNeighborsClassifier model")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
dtc= DecisionTreeClassifier()
dtc.fit(X_train,y_train)
y_pred=dtc.predict(X_test)
##checking the accuracy

from sklearn.metrics import accuracy_score
ac=accuracy_score(y_test,y_pred)
ac
# Out:
# 0.9666666666666667

# %%
##confusion matrix

from sklearn.metrics import confusion_matrix
matrix=metrics.confusion_matrix(y_pred,y_test)
matrix
matrix=metrics.confusion_matrix(y_pred,y_test)
cmap = sns.diverging_palette(100, 8, as_cmap=True)
sns.heatmap(matrix,annot=True,cmap=cmap,fmt='0.1f')
plt.xlabel("Predicted Values")
plt.ylabel("Test Values")
plt.title("Confusion Matrix for DecisionTreeClassifier model")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
y_pred=rfc.predict(X_test)
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9666666666666667

# %%
##confusion matrix

from sklearn.metrics import confusion_matrix
matrix=metrics.confusion_matrix(y_pred,y_test)
matrix
matrix=metrics.confusion_matrix(y_pred,y_test)
cmap = sns.diverging_palette(650, 180, as_cmap=True)
sns.heatmap(matrix,annot=True,cmap=cmap,fmt='0.1f')
plt.xlabel("Predicted Values")
plt.ylabel("Test Values")
plt.title("Confusion Matrix for RandomForestClassifier model")
plt.show()

# %%
model_accuracies = {}

# List of models to evaluate
models = [
    ('GaussianNB', GaussianNB()),
    ('Support Vector Machine', SVC()),
    ('KNeighborsClassifier',  KNeighborsClassifier()),
     ('DecisionTreeClassifier',DecisionTreeClassifier())
]

# Train and evaluate each model
for name, model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    model_accuracies[name] = accuracy

# Create a DataFrame for better visualization
accuracy_df = pd.DataFrame(list(model_accuracies.items()), columns=['Model', 'Accuracy'])

# %%
accuracy_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_18674_row0_col1, #T_18674_row2_col1, #T_18674_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_18674_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_18674">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18674_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_18674_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18674_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18674_row0_col0" class="data row0 col0" >GaussianNB</td>
#       <td id="T_18674_row0_col1" class="data row0 col1" >0.966667</td>
#     </tr>
#     <tr>
#       <th id="T_18674_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18674_row1_col0" class="data row1 col0" >Support Vector Machine</td>
#       <td id="T_18674_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18674_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18674_row2_col0" class="data row2 col0" >KNeighborsClassifier</td>
#       <td id="T_18674_row2_col1" class="data row2 col1" >0.966667</td>
#     </tr>
#     <tr>
#       <th id="T_18674_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18674_row3_col0" class="data row3 col0" >DecisionTreeClassifier</td>
#       <td id="T_18674_row3_col1" class="data row3 col1" >0.966667</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = SVC()
model.fit(X_train, y_train)

# Save the model as a pickle file
with open('Iris_Flower.pkl', 'wb') as f:
    pickle.dump(model, f)

# Load the saved model
with open('Iris_Flower.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Function for prediction with user input
def predict_iris(sepal_length, sepal_width, petal_length, petal_width):
    input_data = [[sepal_length, sepal_width, petal_length, petal_width]]
    predicted = loaded_model.predict(input_data)[0]
    return predicted

# %%
# Example usage
predicted_species = predict_iris(6.7,3.0,2.2,1.3)
print("Predicted Iris Species:", predicted_species)
# Out:
# Predicted Iris Species: 2
